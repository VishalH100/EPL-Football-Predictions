# %% [markdown]
# <h1>Combining football-data and making changes to the data

# %%
import constants as c
import pandas as pd

# %%
# Load the CSV files
df1 = pd.read_csv(c.fb_data_18_19)
df2 = pd.read_csv(c.fb_data_19_20)
df3 = pd.read_csv(c.fb_data_20_21)
df4 = pd.read_csv(c.fb_data_21_22)
df5 = pd.read_csv(c.fb_data_22_23)

# Combine all the dataframes
combined_df = pd.concat([df1, df2, df3, df4, df5], ignore_index=True)

# Rename columns
combined_df.rename(columns={'HomeTeam': 'Home_Team', 'AwayTeam': 'Away_Team'}, inplace=True)

# Define reverse mapping dictionary from df
team_mapping = {
    'Crystal Palace': 'Crystal Palace',
    'Chelsea': 'Chelsea',
    'Man United': 'Manchester Utd',
    'Arsenal': 'Arsenal',
    'Southampton': 'Southampton',
    'Everton': 'Everton',
    'Leicester': 'Leicester City',
    'Aston Villa': 'Aston Villa',
    'Leeds': 'Leeds United',
    'Brentford': 'Brentford',
    'Brighton': 'Brighton',
    'Newcastle': 'Newcastle Utd',
    'West Ham': 'West Ham',
    'Man City': 'Manchester City',
    'Tottenham': 'Tottenham',
    'Liverpool': 'Liverpool',
    'Fulham': 'Fulham',
    'Bournemouth': 'Bournemouth',
    'Wolves': 'Wolves',
    "Nott'm Forest": "Nott'ham Forest",
    'Norwich': 'Norwich City',
    'Burnley': 'Burnley',
    'Watford': 'Watford',
    'Sheffield United': 'Sheffield Utd',
    'West Brom': 'West Brom',
    'Huddersfield': 'Huddersfield',
    'Cardiff': 'Cardiff City'
}

# Map values in combined_df using the mapping dictionary
combined_df['Home_Team'] = combined_df['Home_Team'].map(team_mapping)
combined_df['Away_Team'] = combined_df['Away_Team'].map(team_mapping)


# Save the combined dataframe to a new CSV file
combined_df.to_csv(c.combined_df_filepath, index=False)

combined_df.head(5)
# Out:
#   Div        Date       Home_Team       Away_Team  FTHG  FTAG FTR  HTHG  HTAG  \
# 0  E0  10-08-2018  Manchester Utd  Leicester City     2     1   H     1     0
# 1  E0  11-08-2018     Bournemouth    Cardiff City     2     0   H     1     0
# 2  E0  11-08-2018          Fulham  Crystal Palace     0     2   A     0     1
# 3  E0  11-08-2018    Huddersfield         Chelsea     0     3   A     0     2
# 4  E0  11-08-2018   Newcastle Utd       Tottenham     1     2   A     1     2
#
#   HTR  ... AvgC<2.5  AHCh  B365CAHH  B365CAHA  PCAHH  PCAHA  MaxCAHH  MaxCAHA  \
# 0   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 1   H  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 2   A  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 3   A  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
# 4   A  ...      NaN   NaN       NaN       NaN    NaN    NaN      NaN      NaN
#
#    AvgCAHH  AvgCAHA
# ...

# %% [markdown]
# <h1>Combining Kaggle and Football-data

# %%
import pandas as pd

# Read files into pandas dataframes
file1_df = pd.read_csv(c.combined_df_filepath, encoding ='latin')
file2_df = pd.read_csv(c.EPL_2018_2023, encoding='latin')

# Merge dataframes based on Date, Home_Team, and Away_Team
merged_df = pd.merge(file2_df, file1_df[['Season','Home_Team', 'Away_Team', 'B365H', 'B365D', 'B365A']], 
                    on=['Season','Home_Team', 'Away_Team'], how='left')

# Write merged dataframe back to file2
merged_df.to_csv(c.final_data, index=False)
merged_df
# Out:
#       Week        Date   Time       Home_Team  Home_xG Score  Away_xG  \
# 0       38  28-05-2023  16:30  Crystal Palace      1.4   11      0.5
# 1       38  28-05-2023  16:30         Chelsea      2.2   11      1.7
# 2       38  28-05-2023  16:30  Manchester Utd      2.9   21      1.8
# 3       38  28-05-2023  16:30         Arsenal      2.8   50      0.5
# 4       38  28-05-2023  16:30     Southampton      1.8   44      4.0
# ...    ...         ...    ...             ...      ...   ...      ...
# 1895     1  11-08-2018  15:00     Bournemouth      2.2   20      1.4
# 1896     1  11-08-2018  15:00         Watford      1.2   20      0.3
# 1897     1  11-08-2018  15:00    Huddersfield      0.3   03      1.9
# 1898     1  11-08-2018  17:30          Wolves      1.0   22      1.0
# 1899     1  10-08-2018  20:00  Manchester Utd      1.5   21      1.8
#
#             Away_Team  Attendance                     Venue         Referee  \
# ...

# %% [markdown]
# <h1>All Kaggle data combined

# %%
import pandas as pd
df = pd.read_csv(c.EPL_2018_2023, encoding='latin')
df.head(5)
